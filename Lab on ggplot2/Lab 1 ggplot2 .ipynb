# %% [markdown]
# # Computer exercise 1: Introduction to ggplot2

# %%
library(ggplot2)

# %% [markdown]
# 1. View the documentation for the two datasets.

# %%
?diamonds

# %%
?msleep

# %% [markdown]
# Check the data structures: how many observations and variables are there and what type of variables (numeric, categorical, etc.) are there?

# %%
str(diamonds)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	53940 obs. of  10 variables:
#  $ carat  : num  0.23 0.21 0.23 0.29 0.31 0.24 0.24 0.26 0.22 0.23 ...
#  $ cut    : Ord.factor w/ 5 levels "Fair"<"Good"<..: 5 4 2 4 2 3 3 3 1 3 ...
#  $ color  : Ord.factor w/ 7 levels "D"<"E"<"F"<"G"<..: 2 2 2 6 7 7 6 5 2 5 ...
#  $ clarity: Ord.factor w/ 8 levels "I1"<"SI2"<"SI1"<..: 2 3 5 4 2 6 7 3 4 5 ...
#  $ depth  : num  61.5 59.8 56.9 62.4 63.3 62.8 62.3 61.9 65.1 59.4 ...
#  $ table  : num  55 61 65 58 58 57 57 55 61 61 ...
#  $ price  : int  326 326 327 334 335 336 336 337 337 338 ...
#  $ x      : num  3.95 3.89 4.05 4.2 4.34 3.94 3.95 4.07 3.87 4 ...
#  $ y      : num  3.98 3.84 4.07 4.23 4.35 3.96 3.98 4.11 3.78 4.05 ...
#  $ z      : num  2.43 2.31 2.31 2.63 2.75 2.48 2.47 2.53 2.49 2.39 ...

# %%
str(msleep)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	83 obs. of  11 variables:
#  $ name        : chr  "Cheetah" "Owl monkey" "Mountain beaver" "Greater short-tailed shrew" ...
#  $ genus       : chr  "Acinonyx" "Aotus" "Aplodontia" "Blarina" ...
#  $ vore        : chr  "carni" "omni" "herbi" "omni" ...
#  $ order       : chr  "Carnivora" "Primates" "Rodentia" "Soricomorpha" ...
#  $ conservation: chr  "lc" NA "nt" "lc" ...
#  $ sleep_total : num  12.1 17 14.4 14.9 4 14.4 8.7 7 10.1 3 ...
#  $ sleep_rem   : num  NA 1.8 2.4 2.3 0.7 2.2 1.4 NA 2.9 NA ...
#  $ sleep_cycle : num  NA NA NA 0.133 0.667 ...
#  $ awake       : num  11.9 7 9.6 9.1 20 9.6 15.3 17 13.9 21 ...
#  $ brainwt     : num  NA 0.0155 NA 0.00029 0.423 NA NA NA 0.07 0.0982 ...
#  $ bodywt      : num  50 0.48 1.35 0.019 600 ...

# %%
summary(diamonds)
# Out:
#      carat               cut        color        clarity          depth
#  Min.   :0.2000   Fair     : 1610   D: 6775   SI1    :13065   Min.   :43.00
#  1st Qu.:0.4000   Good     : 4906   E: 9797   VS2    :12258   1st Qu.:61.00
#  Median :0.7000   Very Good:12082   F: 9542   SI2    : 9194   Median :61.80
#  Mean   :0.7979   Premium  :13791   G:11292   VS1    : 8171   Mean   :61.75
#  3rd Qu.:1.0400   Ideal    :21551   H: 8304   VVS2   : 5066   3rd Qu.:62.50
#  Max.   :5.0100                     I: 5422   VVS1   : 3655   Max.   :79.00
#                                     J: 2808   (Other): 2531
#      table           price             x                y
#  Min.   :43.00   Min.   :  326   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710   1st Qu.: 4.720
#  Median :57.00   Median : 2401   Median : 5.700   Median : 5.710
#  Mean   :57.46   Mean   : 3933   Mean   : 5.731   Mean   : 5.735
#  3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540   3rd Qu.: 6.540
# ...

# %%
summary(msleep)
# Out:
#      name              genus               vore              order
#  Length:83          Length:83          Length:83          Length:83
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  conservation        sleep_total      sleep_rem      sleep_cycle
#  Length:83          Min.   : 1.90   Min.   :0.100   Min.   :0.1167
#  Class :character   1st Qu.: 7.85   1st Qu.:0.900   1st Qu.:0.1833
#  Mode  :character   Median :10.10   Median :1.500   Median :0.3333
#                     Mean   :10.43   Mean   :1.875   Mean   :0.4396
#                     3rd Qu.:13.75   3rd Qu.:2.400   3rd Qu.:0.5792
#                     Max.   :19.90   Max.   :6.600   Max.   :1.5000
#                                     NA's   :22      NA's   :51
#      awake          brainwt            bodywt
#  Min.   : 4.10   Min.   :0.00014   Min.   :   0.005
# ...

# %% [markdown]
# Compute summary statistics (means, median, min, max, standard deviations, counts for categorical variables). Are there any missing values?

# %%
mean(diamonds$carat)
# Out:
# [1] 0.7979397

# %%
sd(diamonds$carat)
# Out:
# [1] 0.4740112

# %%
subset(diamonds, price == max(price))
subset(diamonds, price == min(price))
# Out:
#   carat cut     color clarity depth table price x   y    z
# 1 2.29  Premium I     VS2     60.8  60    18823 8.5 8.47 5.16
#   carat cut     color clarity depth table price x    y    z
# 1 0.23  Ideal   E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium E     SI1     59.8  61    326   3.89 3.84 2.31

# %% [markdown]
# Missing Data

# %%
#is.na(msleep)
sum(is.na(msleep$sleep_rem))
sum(is.na(msleep))
which(is.na(msleep))
sum(is.na(diamonds))
# Out:
# [1] 22
# [1] 136
#   [1] 174 221 223 224 229 235 239 334 338 340 348 359 361 366 370 373 375 377
#  [19] 382 386 389 390 393 397 398 400 401 405 407 408 410 411 412 413 414 415
#  [37] 499 506 508 519 525 534 539 542 543 545 549 550 551 554 555 558 563 568
#  [55] 573 574 578 580 582 583 584 589 591 592 594 596 597 600 602 605 607 608
#  [73] 611 612 613 614 616 617 618 620 622 625 626 627 628 630 632 633 634 636
#  [91] 637 638 639 640 641 642 643 644 646 647 650 651 653 656 657 659 661 662
# [109] 663 748 750 753 754 755 760 774 777 778 782 784 786 788 791 793 794 798
# [127] 800 803 804 806 807 808 812 819 823 827
# [1] 0

# %% [markdown]
# # Our First Plot

# %% [markdown]
# As a first example, let’s make a scatterplot by plotting the total sleep time of an animal against the REM sleep time of an animal. The code for doing this using ggplot2 is:

# %%
ggplot(msleep, aes(x = sleep_total, y = sleep_rem)) + geom_point()
# Out:
# Warning message:
# “Removed 22 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# The code consists of three parts:
#
# • Data: given by the first argument in the call to ggplot: msleep
#
# • Aesthetics: given by the second argument in the ggplot call: aes, where we map sleep_total to
# the x-axis and sleep_rem to the y-axis.
#
# • Geoms: given by geom_point, meaning that the observations will be represented by points.
#
# That is, the syntax to create the plot is ggplot(data, aes) + geom. All plots created using ggplot2 follow this pattern. The plus sign is important, as it implies that we can add more geoms to the plot, for instance a trend line, and perhaps other things as well. We will return to that shortly.
#
# Unless the user specifies otherwise, the first two arguments to aes will always be mapped to x and y, meaning that we can simplify the code above by removing the x = and y = bits (at the cost of a slight reduction in readbility). Moreover, it is considered good style to insert a line break after the + sign. The resulting code is:

# %%
 ggplot(msleep, aes(sleep_total, sleep_rem)) + 
geom_point()
# Out:
# Warning message:
# “Removed 22 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Note that this does not change the plot in any way - the difference is merely in the style of the code.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# Create a scatterplot with total sleeping time along the x-axis and time awake along the y-axis (using the msleep data). What pattern do you see? Can you explain it?

# %%
ggplot(msleep, aes(x=sleep_total, y= awake)) +
  geom_point()
## We can say that the more time they sleep the less time they are awake
# Out:
# plot without title

# %% [markdown]
# #### Colours, shapes and axis labels

# %% [markdown]
# You now know how to make scatterplots, but if you plan to show your plot to someone else, there are probably a few changes that you’d like to make. For instance, it’s usually a good idea to change the label for the x-axis from the variable name “sleep_total” to something like “Total sleep time (h)”. This is done by using the + sign again, adding a call to xlab to the plot:

# %%
ggplot(msleep, aes(sleep_total, sleep_rem)) + geom_point() +
xlab("Total sleep time (h)")
# Out:
# Warning message:
# “Removed 22 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Note that the plus signs must be placed at the end of a row rather than at the beginning. To change the y-axis label, add ylab instead.

# %% [markdown]
# ##### To change the colour of the points, you can set the colour in geom_points:

# %%
ggplot(msleep, aes(sleep_total, sleep_rem)) + 
geom_point(colour = "red") + 
xlab("Total sleep time (h)")
# Out:
# Warning message:
# “Removed 22 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Alternatively, you may want to use the colours of the point to separate different categories. This is done by adding a colour argument to aes, since you are now mapping a data variable to a visual property. For instance, we can use the variable vore to show differences between herbivores, carnivores and omnivores:

# %%
ggplot(msleep, aes(sleep_total, sleep_rem, colour = vore)) + 
geom_point() +
xlab("Total sleep time (h)") +
ylab("Sleep Rem (h)")
# Out:
# Warning message:
# “Removed 22 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# What happens if we use a continuous variable, such as the sleep cycle length sleep_cycle to set the colour?

# %%
ggplot(msleep, aes(sleep_total, sleep_rem, colour = sleep_cycle)) + 
geom_point() +
xlab("Total sleep time (h)")+
ylab("Sleep Rem (h)")
# Out:
# Warning message:
# “Removed 22 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# In the next two exercises, you will create scatterplots for the diamonds data.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Create a scatterplot with carat along the x-axis and price along the y-axis. Change the x-axis label to read “Weight of the diamond (carat)” and the y-axis label to “Price (USD)”. Use cut to set the colour of the points.

# %%
ggplot(diamonds, aes(carat, price, colour = cut)) + 
  geom_point() +
  xlab("Weight of the diamond (carat)") +
  ylab("Price (USD)")
# Out:
# plot without title

# %% [markdown]
# Try adding the argument alpha = 1 to geom_points, i.e. geom_points(alpha = 1). Does anything happen? Try changing the 1 to 0.5 and 0.25 and see how that affects the plot.

# %%
ggplot(diamonds, aes(carat, price, colour = cut)) + 
  geom_point(alpha = 0.5) +
  xlab("Weight of the diamond (carat)") +
  ylab("Price (USD)")
# Out:
# plot without title

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Similar to how you changed the colour of the points, you can also change their size and shape. The arguments for this are called size and shape.

# %% [markdown]
# Change the scatterplot from Exercise 3 so that diamonds with different cut qualities are represented by different shapes?

# %%
ggplot(diamonds, aes(carat, price, shape = cut)) + 
  geom_point() +
  xlab("Weight of the diamond (carat)") +
  ylab("Price (USD)")
# Out:
# Warning message:
# “Using shapes for an ordinal variable is not advised”
# plot without title

# %% [markdown]
# Then change it so that the size of each point is determined by the diamond’s length (x).

# %%
ggplot(diamonds, aes(carat, price, size=x)) + 
  geom_point(aes(shape = cut, colour = cut)) +
  xlab("Weight of the diamond (carat)") +
  ylab("Price (USD)")
# Out:
# Warning message:
# “Using shapes for an ordinal variable is not advised”
# plot without title

# %% [markdown]
# ## Axis limits and scales

# %% [markdown]
# Next, assume that we wish to study the relationship between animals’ brain sizes and their total sleep times. We create a scatterplot using:

# %%
ggplot(msleep, aes(brainwt, sleep_total, colour = vore)) + geom_point() +
xlab("Brain weight") + ylab("Total sleep time")
# Out:
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# There are two animals with brains that are much heavier than the rest (African elephant and Asian elephant). These outliers distort the plot, making it difficult to spot any patterns. We can try changing the x-axis to only go from 0 to 1.5 by adding xlim to the plot, to see if that improves it:

# %%
ggplot(msleep, aes(brainwt, sleep_total, colour = vore)) + geom_point() +
xlab("Brain weight") + ylab("Total sleep time") + xlim(0, 1.5)
# Out:
# Warning message:
# “Removed 29 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# This is slightly better, but we still have a lot of points clustered near the y-axis. If instead we wished to change the limits of the y-axis, we would have used ylim in the same fashion.

# %% [markdown]
# Another option is to resacle the x-axis by applying a log transform to the brain weights, which we can do directly in aes:

# %%
ggplot(msleep, aes(log(brainwt), sleep_total, colour = vore)) + geom_point() +
xlab("log(Brain weight)") + ylab("Total sleep time")
# Out:
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# This is a better-looking scatterplot, with a weak declining trend. We didn’t have to remove the outliers (the elephants) to create it, which is good. The downside is that the x-axis now has become difficult to interpret. A third option that mitigates this is to add scale_x_log10 to the plot, which changes the scale of the x-axis to a log10 scale (which increases interpretability because the values shown at the ticks still are on the original x-scale).

# %%
ggplot(msleep, aes(brainwt, sleep_total, colour = vore)) + geom_point() +
xlab("Brain weight (logarithmic scale)") + ylab("Total sleep time") +
scale_x_log10()
# Out:
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# Using the msleep data, create a plot of log-transformed body weight versus log-transformed brain weight. Use total sleep time to set the colours of the points. Change the text on the axes to something informative.

# %%
ggplot(msleep, aes(log(bodywt), log(brainwt), colour = sleep_total)) + 
  geom_point() +
  xlab("log(Body weight)") + ylab("Log(Brain Wt)")
# Out:
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Comparing groups

# %% [markdown]
# We frequently wish to make visuals comparison of different groups. One way to display categorical variables in plots is to use facetting, i.e. to create a grid of plots corresponding to the different categories. For instance, in our plot of animal brain weight versus total sleep time, we may wish to separate the different feeding behaviours (omnivores, carnivores, etc.) in the msleep data using facetting instead of different coloured points. In ggplot2 we do this by adding a call to facet_wrap to the plot:

# %%
ggplot(msleep, aes(brainwt, sleep_total)) + geom_point() +
xlab("Brain weight (logarithmic scale)") + ylab("Total sleep time") +
scale_x_log10() +
facet_wrap(~ vore)
# Out:
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# Note that the x-axes and y-axes of the different plots in the grid all have the same scale and limits.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# Using the diamonds data, create a scatterplot with carat along the x-axis and price along the y-axis, facetted by cut.

# %%
ggplot(diamonds, aes(carat, price)) + geom_point() +
  xlab("Carat (logarithmic scale)") + ylab("Price") +
  scale_x_log10() +
  facet_wrap(~ cut)
# Out:
# plot without title

# %% [markdown]
# Read the documentation for facet_wrap (?facet_wrap). How can you change the number of rows in the plot grid? Create the same plot as in part 1, but with 5 rows.

# %%
?facet_wrap

# %%
ggplot(diamonds, aes(carat, price)) + geom_point() +
  xlab("Carat (logarithmic scale)") + ylab("Price") +
  scale_x_log10() +
  facet_wrap(vars(cut), nrow = 5)
# Out:
# plot without title

# %% [markdown]
# # Boxplots

# %% [markdown]
# Another option for comparing groups is boxplots (also called box-and-whiskers plots). Using ggplot2, we create boxplots for animal sleep times, grouped by feeding behaviour, with

# %%
 ggplot(msleep, aes(vore, sleep_total)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Note that just as for a scatterplot, the code consists of three parts:
# • Data: given by the first argument in the call to ggplot: msleep
# • Aesthetics: given by the second argument in the ggplot call: aes, where we map vore to the x-axis
# and sleep_total to the y-axis.
# • Geoms: given by geom_boxplot, meaning that the data will be visualised with boxplots.

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# Using the diamonds data, create boxplots of diamond prices, grouped by cut.

# %%
ggplot(diamonds, aes(cut, price)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Read the documentation for geom_boxplot. How can you change the colours of the boxes and their
# outlines?

# %%
?geom_boxplot

# %%
ggplot(diamonds, aes(cut, price)) + 
  geom_boxplot(aes(fill=cut,colour=cut), outlier.colour = "red", outlier.shape = 0.2)
# Out:
# plot without title

# %% [markdown]
# Replace cut by reorder(cut, price) in the plot’s aestethics. What does reorder do? What is the result?

# %%
ggplot(diamonds, aes(price, cut)) + 
  geom_boxplot(aes(fill=cut,colour=cut), outlier.colour = "red", outlier.shape = 0.2)
# Out:
# plot without title

# %% [markdown]
# Add geom_jitter(size = 0.1, alpha = 0.2) to the plot. What happens?

# %%
ggplot(diamonds, aes(cut, price)) + 
  geom_boxplot(aes(fill=cut,colour=cut), outlier.colour = "red", outlier.shape = 0.2) +
  geom_jitter(size = 0.1, alpha = 0.2)
# Out:
# plot without title

# %% [markdown]
# ## Histograms

# %% [markdown]
# To show the distribution of a continuous variable, we can use a histogram, in which the data is split into a number of bins and the number of observations in each bin is shown by a bar. The ggplot2 code for histograms follows the same pattern as other plots:

# %%
 ggplot(msleep, aes(sleep_total)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# As before, the three parts are:
#
# • Data: given by the first argument in the call to ggplot: msleep
#
# • Aesthetics: given by the second argument in the ggplot call: aes, where we map sleep_total to
# the x-axis.
#
# • Geoms: given by geom_histogram, meaning that the data will be visualised by a histogram.

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# Using the diamonds data, create a histogram of diamond prices.

# %%
ggplot(diamonds, aes(price)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# Create histograms of diamond prices for different cuts, using facetting.

# %%
ggplot(diamonds, aes(x = price, fill = cut)) +
    geom_histogram(bandwidth=500) +
    facet_wrap( ~ color)
# Out:
# Warning message:
# “Ignoring unknown parameters: bandwidth”`stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# Add a suitable argument to geom_histogram to add black outlines around the bars

# %%
ggplot(diamonds, aes(x = price, fill = cut)) +
    geom_histogram(colour= "black",bandwidth=500)
# Out:
# Warning message:
# “Ignoring unknown parameters: bandwidth”`stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# # Categorical data

# %% [markdown]
# When visualising categorical data, we typically try to show the counts, i.e. the number of observations, for each category. The most common plot for this type of data is the bar chart.

# %% [markdown]
# ## Bar charts

# %% [markdown]
# Bar charts are discrete analogues to histograms, where the category counts are represented by bars. The code for creating them is:

# %%
 ggplot(msleep, aes(vore)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# As always, the three parts are:
#
# • Data: given by the first argument in the call to ggplot: msleep
#
# • Aesthetics: given by the second argument in the ggplot call: aes, where we map vore to the x-axis.
#
# • Geoms: given by geom_bar, meaning that the data will be visualised by a bar chart.

# %% [markdown]
# ### Exercise 9

# %% [markdown]
# Using the diamonds data, create a bar chart of cuts.

# %%
ggplot(diamonds, aes(cut)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# Add different colours to the bars by adding a fill argument to geom_bar.

# %%
ggplot(diamonds, aes(cut, fill = cut)) + 
geom_bar()
# Out:
# plot without title

# %% [markdown]
# Check the documentation for geom_bar. How can you decrease the width of the bars?

# %%
?geom_bar

# %%
ggplot(diamonds, aes(cut)) + geom_bar(width=0.4)
# Out:
# plot without title

# %% [markdown]
# Return to the code you used for part 1. Add fill = clarity to the aes. What happens?

# %%
 ggplot(diamonds, aes(cut, fill = clarity)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# Next, add position = "dodge" to geom_bar. What happens?

# %%
 ggplot(diamonds, aes(cut, fill = clarity)) + geom_bar(position = "dodge")
# Out:
# plot without title

# %% [markdown]
# Return to the code you used for part 1. Add coord_flip() to the plot. What happens?

# %%
ggplot(diamonds, aes(cut)) + 
geom_bar() +
coord_flip()
# Out:
# plot without title
